# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../dataset/pompa-attack-2.csv")

df = df[["adc_level","adc_temp","adc_flow","adc_pressure_left","adc_pressure_right"]]
scaler = joblib.load("../../scaler/pit/uae-5.gz")

scaled = scaler.transform(df)

# %%
scaled_df = pd.DataFrame(scaled, columns = ["adc_level","adc_temp","adc_flow","adc_pressure_left","adc_pressure_right"])
scaled_df = scaled_df[5:]
scaled_df.head()
# Out:
#    adc_level  adc_temp  adc_flow  adc_pressure_left  adc_pressure_right
# 5   0.266667  0.452830  0.464286           0.674419            0.409091
# 6   0.300000  0.471698  0.482143           0.697674            0.545455
# 7   0.316667  0.452830  0.410714           0.720930            0.500000
# 8   0.516667  0.490566  0.482143           0.697674            0.363636
# 9   0.600000  0.509434  0.482143           0.627907            0.454545

# %%
predict_df = pd.read_csv("../../dataset/pit/test-predict.csv")

predict_df.head()
# Out:
#    adc_level  adc_temp  adc_flow  adc_pressure_left  adc_pressure_right
# 0   0.343677  0.467309  0.482366           0.692720            0.495900
# 1   0.324042  0.462770  0.495339           0.692538            0.499263
# 2   0.385821  0.462513  0.509327           0.696516            0.503576
# 3   0.402254  0.463992  0.498839           0.684908            0.486596
# 4   0.561227  0.462771  0.503157           0.677025            0.473141

# %%
for column in ["adc_level","adc_temp","adc_flow","adc_pressure_left","adc_pressure_right"]:
    plt.figure(figsize=(100,100))

    ax = scaled_df[[column]].plot()
    predict_df[[column]].plot(ax=ax, color='red', linewidth=3)

    plt.show()
