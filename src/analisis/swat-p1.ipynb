# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("../../dataset/swat-p1.xlsx")
# Out:
# d:\Projects\TA\ml-model\env\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df = df[16000:]

# %%
df.head()
# Out:
#                     Timestamp    FIT101    LIT101  MV101  P101  P102  \
# 16000   22/12/2015 8:56:40 PM  2.571502  508.4410      2     2     1
# 16001   22/12/2015 8:56:41 PM  2.614419  508.3625      2     2     1
# 16002   22/12/2015 8:56:42 PM  2.638440  508.5980      2     2     1
# 16003   22/12/2015 8:56:43 PM  2.659578  508.7550      2     2     1
# 16004   22/12/2015 8:56:44 PM  2.662781  509.2260      2     2     1
#
#       Normal/Attack
# 16000        Normal
# 16001        Normal
# 16002        Normal
# 16003        Normal
# 16004        Normal

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.to_csv("../../dataset/swat-p1.csv")
